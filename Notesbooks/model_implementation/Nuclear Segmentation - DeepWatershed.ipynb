# %% [markdown]
# This notebook is part of the `deepcell-tf` documentation: https://deepcell.readthedocs.io/.

# %% [markdown]
# # Training a segmentation model
#
# `deepcell-tf` leverages [Jupyter Notebooks](https://jupyter.org) in order to train models. Example notebooks are available for most model architectures in the [notebooks folder](https://github.com/vanvalenlab/deepcell-tf/tree/master/notebooks). Most notebooks are structured similarly to this example and thus this notebook serves as a core reference for the deepcell approach to model training.

# %%
import os

import matplotlib.pyplot as plt
import numpy as np
from skimage.feature import peak_local_max
import tensorflow as tf

from deepcell.applications import mesmer
from deepcell.image_generators import CroppingDataGenerator
from deepcell.losses import weighted_categorical_crossentropy
from deepcell.model_zoo.panopticnet import PanopticNet
from deepcell.utils.train_utils import count_gpus, rate_scheduler
from deepcell_toolbox.deep_watershed import deep_watershed
from deepcell_toolbox.metrics import Metrics
from deepcell_toolbox.processing import histogram_normalization
from skimage.transform import resize

# %% [markdown]
# ## File paths

# %%
data_dir = 'tissuenet_v1.1'
#data_dir = 'DynamicNuclearNet-segmentation-v1_0'
model_path = 'Mesmer'
metrics_path = 'metrics.yaml'
train_log = 'train_log.csv'

# %% [markdown]
# ## Load the data
#
# Loads Tissue net dataset

# %%
data_dir = 'DynamicNuclearNet-segmentation-v1_0'
with np.load(os.path.join(data_dir, 'train.npz')) as data:
    X_train = data['X']
    y_train = data['y']
    
with np.load(os.path.join(data_dir, 'val.npz')) as data:
    X_val = data['X']
    y_val = data['y']
    
with np.load(os.path.join(data_dir, 'test.npz')) as data:
    X_test = data['X']
    y_test = data['y']

# %%
with np.load(os.path.join(data_dir, 'tissuenet_v1.1_train.npz')) as data:
    X_train = data['X']
    y_train = data['y']
    
with np.load(os.path.join(data_dir, 'tissuenet_v1.1_val.npz')) as data:
    X_val = data['X']
    y_val = data['y']
    
with np.load(os.path.join(data_dir, 'tissuenet_v1.1_test.npz')) as data:
    X_test = data['X']
    y_test = data['y']

# %% [markdown]
# X contains main images, Y contains segmentation mask
# X and Y train = (2580, 512, 512, 2)
# X and Y val = (3118, 256, 256, 2)
# X and Y test = (1324, 256, 256, 2)
#
# 4th dimension contains membrane and nuclear

# %%
print("Train data shapes:", X_train.shape, "and" ,y_train.shape)
print("Validation data shapes:", X_val.shape, "and" , y_val.shape)
print("Test data shapes:", X_test.shape, "and" , y_test.shape)
# Out:
# Train data shapes: (4950, 512, 512, 1) and (4950, 512, 512, 1)
# Validation data shapes: (1417, 512, 512, 1) and (1417, 512, 512, 1)
# Test data shapes: (717, 512, 512, 1) and (717, 512, 512, 1)

# %%
plt.imshow(X_train[0][1])

# %% [markdown]
# ## Training parameters

# %% [markdown]
# The majority of DeepCell models support a variety backbone choices specified in the “backbone” parameter. Backbones are provided through keras_applications and can be instantiated with weights that are pretrained on ImageNet.

# %%
# Model architecture
backbone = "efficientnetv2bl"
location = True
pyramid_levels = ["P1","P2","P3","P4","P5","P6","P7"]

# %%
# Augmentation and transform parameters
seed = 0
min_objects = 1
zoom_min = 0.75
crop_size = 256
outer_erosion_width = 1
inner_distance_alpha = "auto"
inner_distance_beta = 1
inner_erosion_width = 0

# %%
# Post processing parameters
maxima_threshold = 0.1
interior_threshold = 0.01
exclude_border = False
small_objects_threshold = 0
min_distance = 10

# %%
# Training configuration
epochs = 16
batch_size = 16
lr = 1e-4

# %% [markdown]
# ## Create data generators

# %%
# data augmentation parameters
zoom_max = 1 / zoom_min

# Preprocess the data
X_train = histogram_normalization(X_train)
X_val = histogram_normalization(X_val)

# use augmentation for training but not validation
datagen = CroppingDataGenerator(
    rotation_range=180,
    zoom_range=(zoom_min, zoom_max),
    horizontal_flip=True,
    vertical_flip=True,
    crop_size=(crop_size, crop_size),
)

datagen_val = CroppingDataGenerator(
    crop_size=(crop_size, crop_size)
)

# %%
transforms = ["inner-distance", "outer-distance", "fgbg"]

transforms_kwargs = {
    "outer-distance": {"erosion_width": outer_erosion_width},
    "inner-distance": {
        "alpha": inner_distance_alpha,
        "beta": inner_distance_beta,
        "erosion_width": inner_erosion_width,
    },
}

train_data = datagen.flow(
    {'X': X_train, 'y': y_train},
    seed=seed,
    min_objects=min_objects,
    transforms=transforms,
    transforms_kwargs=transforms_kwargs,
    batch_size=batch_size,
)

print("Created training data generator.")

val_data = datagen_val.flow(
    {'X': X_val, 'y': y_val},
    seed=seed,
    min_objects=min_objects,
    transforms=transforms,
    transforms_kwargs=transforms_kwargs,
    batch_size=batch_size,
)

print("Created validation data generator.")
# Out:
# Created training data generator.
# Created validation data generator.

# %%
train_data.output_size
# Out:
# (256, 256)

# %%
val_data.output_size
# Out:
# (256, 256)

# %% [markdown]
# Visualize the data generator output.

# %%
inputs, outputs = train_data.next()

img = inputs[0]
inner_distance = outputs[0]
outer_distance = outputs[1]
fgbg = outputs[2]

fig, axes = plt.subplots(1, 4, figsize=(15, 15))

axes[0].imshow(img[..., 0])
axes[0].set_title('Source Image')

axes[1].imshow(inner_distance[0, ..., 0])
axes[1].set_title('Inner Distance')

axes[2].imshow(outer_distance[0, ..., 0])
axes[2].set_title('Outer Distance')

axes[3].imshow(fgbg[0, ..., 0])
axes[3].set_title('Foreground/Background')

plt.show()

# %% [markdown]
# ## Create the PanopticNet Model
#
# Here we instantiate a `PanopticNet` model from `deepcell.model_zoo` using 3 semantic heads:
# inner distance (1 class),
# outer distance (1 class),
# foreground/background distance (2 classes)

# %%
input_shape = (crop_size, crop_size, 1)

model = PanopticNet(
    backbone=backbone,
    input_shape=input_shape,
    norm_method=None,
    num_semantic_classes=[1, 1, 2],  # inner distance, outer distance, fgbg
    location=location, 
    include_top=True,
    backbone_levels=["C1", "C2", "C3", "C4", "C5"],
    pyramid_levels=pyramid_levels,
)

# %% [markdown]
# ### Create a loss function for each semantic head
#
# Each semantic head is trained with it's own loss function. Mean Square Error is used for regression-based heads, whereas `weighted_categorical_crossentropy` is used for classification heads.
#
# The losses are saved as a dictionary and passed to `model.compile`.

# %%
def semantic_loss(n_classes):
    def _semantic_loss(y_pred, y_true):
        if n_classes > 1:
            return 0.01 * weighted_categorical_crossentropy(
                y_pred, y_true, n_classes=n_classes
            )
        return tf.keras.losses.MSE(y_pred, y_true)

    return _semantic_loss

loss = {}

# Give losses for all of the semantic heads
for layer in model.layers:
    if layer.name.startswith("semantic_"):
        n_classes = layer.output_shape[-1]
        loss[layer.name] = semantic_loss(n_classes)

optimizer = tf.keras.optimizers.Adam(learning_rate=lr, clipnorm=0.001)

model.compile(loss=loss, optimizer=optimizer)

# %%
loss = {}

# Give losses for all of the semantic heads
for layer in model.layers:
    if layer.name.startswith("semantic_"):
        n_classes = layer.output_shape[-1]
        current_loss = semantic_loss(n_classes)
        
        if isinstance(current_loss, dict):
            # If the loss is a dictionary (multiple losses), assign each one
            for key, value in current_loss.items():
                loss[layer.name + '_' + key] = value
        else:
            # If the loss is a single value, assign it
            loss[layer.name] = current_loss

# Check if all outputs have associated losses
for output_name in model.output_names:
    if output_name not in loss:
        raise ValueError(f"No loss specified for output: {output_name}")

optimizer = tf.keras.optimizers.Adam(learning_rate=lr, clipnorm=0.001)

model.compile(loss=loss, optimizer=optimizer)

# %%
loss["semantic_1"]
# Out:
# <function __main__.semantic_loss.<locals>._semantic_loss(y_true, y_pred)>

# %% [markdown]
# ## Train the model
#
# Call `fit` on the compiled model, along with a default set of callbacks.

# %%
# Clear clutter from previous TensorFlow graphs.
tf.keras.backend.clear_session()

monitor = "val_loss"

csv_logger = tf.keras.callbacks.CSVLogger(train_log)

# Create callbacks for early stopping and pruning.
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        model_path,
        monitor=monitor,
        save_best_only=True,
        verbose=1,
        save_weights_only=False,
    ),
    tf.keras.callbacks.LearningRateScheduler(rate_scheduler(lr=lr, decay=0.99)),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor=monitor,
        factor=0.1,
        patience=5,
        verbose=1,
        mode="auto",
        min_delta=0.0001,
        cooldown=0,
        min_lr=0,
    ),
    tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True),
    csv_logger,
]

print(f"Training on {count_gpus()} GPUs.")

# Train model.
history = model.fit(
    train_data,
    steps_per_epoch=train_data.y.shape[0] // batch_size,
    epochs=epochs,
    validation_data=val_data,
    validation_steps=val_data.y.shape[0] // batch_size,
    callbacks=callbacks,
)

print("Final", monitor, ":", history.history[monitor][-1])
# Out:
# Training on 0 GPUs.
# Epoch 1/16
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\miles\GitHub\mesmer-implementation\Nuclear Segmentation - DeepWatershed.ipynb Cell 31 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/miles/GitHub/mesmer-implementation/Nuclear%20Segmentation%20-%20DeepWatershed.ipynb#X40sZmlsZQ%3D%3D?line=31'>32</a> print(f"Training on {count_gpus()} GPUs.")
#      <a href='vscode-notebook-cell:/c%3A/Users/miles/GitHub/mesmer-implementation/Nuclear%20Segmentation%20-%20DeepWatershed.ipynb#X40sZmlsZQ%3D%3D?line=33'>34</a> # Train model.
# ---> <a href='vscode-notebook-cell:/c%3A/Users/miles/GitHub/mesmer-implementation/Nuclear%20Segmentation%20-%20DeepWatershed.ipynb#X40sZmlsZQ%3D%3D?line=34'>35</a> history = model.fit(
#      <a href='vscode-notebook-cell:/c%3A/Users/miles/GitHub/mesmer-implementation/Nuclear%20Segmentation%20-%20DeepWatershed.ipynb#X40sZmlsZQ%3D%3D?line=35'>36</a>     train_data,
#      <a href='vscode-notebook-cell:/c%3A/Users/miles/GitHub/mesmer-implementation/Nuclear%20Segmentation%20-%20DeepWatershed.ipynb#X40sZmlsZQ%3D%3D?line=36'>37</a>     steps_per_epoch=train_data.y.shape[0] // batch_size,
#      <a href='vscode-notebook-cell:/c%3A/Users/miles/GitHub/mesmer-implementation/Nuclear%20Segmentation%20-%20DeepWatershed.ipynb#X40sZmlsZQ%3D%3D?line=37'>38</a>     epochs=epochs,
#      <a href='vscode-notebook-cell:/c%3A/Users/miles/GitHub/mesmer-implementation/Nuclear%20Segmentation%20-%20DeepWatershed.ipynb#X40sZmlsZQ%3D%3D?line=38'>39</a>     validation_data=val_data,
#      <a href='vscode-notebook-cell:/c%3A/Users/miles/GitHub/mesmer-implementation/Nuclear%20Segmentation%20-%20DeepWatershed.ipynb#X40sZmlsZQ%3D%3D?line=39'>40</a>     validation_steps=val_data.y.shape[0] // batch_size,
#      <a href='vscode-notebook-cell:/c%3A/Users/miles/GitHub/mesmer-implementation/Nuclear%20Segmentation%20-%20DeepWatershed.ipynb#X40sZmlsZQ%3D%3D?line=40'>41</a>     callbacks=callbacks,
#      <a href='vscode-notebook-cell:/c%3A/Users/miles/GitHub/mesmer-implementation/Nuclear%20Segmentation%20-%20DeepWatershed.ipynb#X40sZmlsZQ%3D%3D?line=41'>42</a> )
#      <a href='vscode-notebook-cell:/c%3A/Users/miles/GitHub/mesmer-implementation/Nuclear%20Segmentation%20-%20DeepWatershed.ipynb#X40sZmlsZQ%3D%3D?line=43'>44</a> print("Final", monitor, ":", history.history[monitor][-1])
#
# File c:\Users\miles\GitHub\mesmer-implementation\.venv\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File c:\Users\miles\GitHub\mesmer-implementation\.venv\lib\site-packages\tensorflow\python\framework\func_graph.py:1147, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    1145 except Exception as e:  # pylint:disable=broad-except
#    1146   if hasattr(e, "ag_error_metadata"):
# -> 1147     raise e.ag_error_metadata.to_exception(e)
#    1148   else:
#    1149     raise
#
# ValueError: in user code:
#
#     File "c:\Users\miles\GitHub\mesmer-implementation\.venv\lib\site-packages\keras\engine\training.py", line 1021, in train_function  *
#         return step_function(self, iterator)
#     File "c:\Users\miles\GitHub\mesmer-implementation\.venv\lib\site-packages\keras\engine\training.py", line 1010, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Users\miles\GitHub\mesmer-implementation\.venv\lib\site-packages\keras\engine\training.py", line 1000, in run_step  **
#         outputs = model.train_step(data)
#     File "c:\Users\miles\GitHub\mesmer-implementation\.venv\lib\site-packages\keras\engine\training.py", line 864, in train_step
#         return self.compute_metrics(x, y, y_pred, sample_weight)
#     File "c:\Users\miles\GitHub\mesmer-implementation\.venv\lib\site-packages\keras\engine\training.py", line 957, in compute_metrics
#         self.compiled_metrics.update_state(y, y_pred, sample_weight)
#     File "c:\Users\miles\GitHub\mesmer-implementation\.venv\lib\site-packages\keras\engine\compile_utils.py", line 438, in update_state
#         self.build(y_pred, y_true)
#     File "c:\Users\miles\GitHub\mesmer-implementation\.venv\lib\site-packages\keras\engine\compile_utils.py", line 358, in build
#         self._metrics = tf.__internal__.nest.map_structure_up_to(y_pred, self._get_metric_objects,
#
#     ValueError: The two structures don't have the same sequence length. Input structure has length 6, while shallow structure has length 3.

# %%
model.summary()
# Out:
# Model: "panopticnet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_0 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  location (Location2D)          (None, 256, 256, 2)  0           ['input_0[0][0]']
#
#  concatenate_location (Concaten  (None, 256, 256, 3)  0          ['input_0[0][0]',
#  ate)                                                             'location[0][0]']
#
#  conv_channels (Conv2D)         (None, 256, 256, 3)  12          ['concatenate_location[0][0]']
#
#  stem_conv (Conv2D)             (None, 128, 128, 32  864         ['conv_channels[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 128, 128, 32  128         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 128, 128, 32  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_project_conv (Conv2D)  (None, 128, 128, 32  9216        ['stem_activation[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 128, 128, 32  128        ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1a_project_activation (Ac  (None, 128, 128, 32  0          ['block1a_project_bn[0][0]']
#  tivation)                      )
#
#  block1a_add (Add)              (None, 128, 128, 32  0           ['block1a_project_activation[0][0
#                                 )                                ]',
#                                                                   'stem_activation[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 128, 128, 32  9216        ['block1a_add[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 128, 128, 32  128        ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_project_activation (Ac  (None, 128, 128, 32  0          ['block1b_project_bn[0][0]']
#  tivation)                      )
#
#  block1b_add (Add)              (None, 128, 128, 32  0           ['block1b_project_activation[0][0
#                                 )                                ]',
#                                                                   'block1a_add[0][0]']
#
#  block1c_project_conv (Conv2D)  (None, 128, 128, 32  9216        ['block1b_add[0][0]']
#                                 )
#
#  block1c_project_bn (BatchNorma  (None, 128, 128, 32  128        ['block1c_project_conv[0][0]']
#  lization)                      )
#
#  block1c_project_activation (Ac  (None, 128, 128, 32  0          ['block1c_project_bn[0][0]']
#  tivation)                      )
#
#  block1c_add (Add)              (None, 128, 128, 32  0           ['block1c_project_activation[0][0
#                                 )                                ]',
#                                                                   'block1b_add[0][0]']
#
#  block1d_project_conv (Conv2D)  (None, 128, 128, 32  9216        ['block1c_add[0][0]']
#                                 )
#
#  block1d_project_bn (BatchNorma  (None, 128, 128, 32  128        ['block1d_project_conv[0][0]']
#  lization)                      )
#
#  block1d_project_activation (Ac  (None, 128, 128, 32  0          ['block1d_project_bn[0][0]']
#  tivation)                      )
#
#  block1d_add (Add)              (None, 128, 128, 32  0           ['block1d_project_activation[0][0
#                                 )                                ]',
#                                                                   'block1c_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 64, 64, 128)  36864       ['block1d_add[0][0]']
#
#  block2a_expand_bn (BatchNormal  (None, 64, 64, 128)  512        ['block2a_expand_conv[0][0]']
#  ization)
#
#  block2a_expand_activation (Act  (None, 64, 64, 128)  0          ['block2a_expand_bn[0][0]']
#  ivation)
#
#  block2a_project_conv (Conv2D)  (None, 64, 64, 64)   8192        ['block2a_expand_activation[0][0]
#                                                                  ']
#
#  block2a_project_bn (BatchNorma  (None, 64, 64, 64)  256         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 64, 64, 256)  147456      ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 64, 64, 256)  1024       ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 64, 64, 256)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_project_conv (Conv2D)  (None, 64, 64, 64)   16384       ['block2b_expand_activation[0][0]
#                                                                  ']
#
#  block2b_project_bn (BatchNorma  (None, 64, 64, 64)  256         ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_add (Add)              (None, 64, 64, 64)   0           ['block2b_project_bn[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 64, 64, 256)  147456      ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 64, 64, 256)  1024       ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 64, 64, 256)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_project_conv (Conv2D)  (None, 64, 64, 64)   16384       ['block2c_expand_activation[0][0]
#                                                                  ']
#
#  block2c_project_bn (BatchNorma  (None, 64, 64, 64)  256         ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_add (Add)              (None, 64, 64, 64)   0           ['block2c_project_bn[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 64, 64, 256)  147456      ['block2c_add[0][0]']
#
#  block2d_expand_bn (BatchNormal  (None, 64, 64, 256)  1024       ['block2d_expand_conv[0][0]']
#  ization)
#
#  block2d_expand_activation (Act  (None, 64, 64, 256)  0          ['block2d_expand_bn[0][0]']
#  ivation)
#
#  block2d_project_conv (Conv2D)  (None, 64, 64, 64)   16384       ['block2d_expand_activation[0][0]
#                                                                  ']
#
#  block2d_project_bn (BatchNorma  (None, 64, 64, 64)  256         ['block2d_project_conv[0][0]']
#  lization)
#
#  block2d_add (Add)              (None, 64, 64, 64)   0           ['block2d_project_bn[0][0]',
#                                                                   'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2D)   (None, 64, 64, 256)  147456      ['block2d_add[0][0]']
#
#  block2e_expand_bn (BatchNormal  (None, 64, 64, 256)  1024       ['block2e_expand_conv[0][0]']
#  ization)
#
#  block2e_expand_activation (Act  (None, 64, 64, 256)  0          ['block2e_expand_bn[0][0]']
#  ivation)
#
#  block2e_project_conv (Conv2D)  (None, 64, 64, 64)   16384       ['block2e_expand_activation[0][0]
#                                                                  ']
#
#  block2e_project_bn (BatchNorma  (None, 64, 64, 64)  256         ['block2e_project_conv[0][0]']
#  lization)
#
#  block2e_add (Add)              (None, 64, 64, 64)   0           ['block2e_project_bn[0][0]',
#                                                                   'block2d_add[0][0]']
#
#  block2f_expand_conv (Conv2D)   (None, 64, 64, 256)  147456      ['block2e_add[0][0]']
#
#  block2f_expand_bn (BatchNormal  (None, 64, 64, 256)  1024       ['block2f_expand_conv[0][0]']
#  ization)
#
#  block2f_expand_activation (Act  (None, 64, 64, 256)  0          ['block2f_expand_bn[0][0]']
#  ivation)
#
#  block2f_project_conv (Conv2D)  (None, 64, 64, 64)   16384       ['block2f_expand_activation[0][0]
#                                                                  ']
#
#  block2f_project_bn (BatchNorma  (None, 64, 64, 64)  256         ['block2f_project_conv[0][0]']
#  lization)
#
#  block2f_add (Add)              (None, 64, 64, 64)   0           ['block2f_project_bn[0][0]',
#                                                                   'block2e_add[0][0]']
#
#  block2g_expand_conv (Conv2D)   (None, 64, 64, 256)  147456      ['block2f_add[0][0]']
#
#  block2g_expand_bn (BatchNormal  (None, 64, 64, 256)  1024       ['block2g_expand_conv[0][0]']
#  ization)
#
#  block2g_expand_activation (Act  (None, 64, 64, 256)  0          ['block2g_expand_bn[0][0]']
#  ivation)
#
#  block2g_project_conv (Conv2D)  (None, 64, 64, 64)   16384       ['block2g_expand_activation[0][0]
#                                                                  ']
#
#  block2g_project_bn (BatchNorma  (None, 64, 64, 64)  256         ['block2g_project_conv[0][0]']
#  lization)
#
#  block2g_add (Add)              (None, 64, 64, 64)   0           ['block2g_project_bn[0][0]',
#                                                                   'block2f_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 32, 32, 256)  147456      ['block2g_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 32, 32, 256)  1024       ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 32, 32, 256)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_project_conv (Conv2D)  (None, 32, 32, 96)   24576       ['block3a_expand_activation[0][0]
#                                                                  ']
#
#  block3a_project_bn (BatchNorma  (None, 32, 32, 96)  384         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 32, 32, 384)  331776      ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 32, 32, 384)  1536       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 32, 32, 384)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_project_conv (Conv2D)  (None, 32, 32, 96)   36864       ['block3b_expand_activation[0][0]
#                                                                  ']
#
#  block3b_project_bn (BatchNorma  (None, 32, 32, 96)  384         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_add (Add)              (None, 32, 32, 96)   0           ['block3b_project_bn[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 32, 32, 384)  331776      ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 32, 32, 384)  1536       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 32, 32, 384)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_project_conv (Conv2D)  (None, 32, 32, 96)   36864       ['block3c_expand_activation[0][0]
#                                                                  ']
#
#  block3c_project_bn (BatchNorma  (None, 32, 32, 96)  384         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_add (Add)              (None, 32, 32, 96)   0           ['block3c_project_bn[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 32, 32, 384)  331776      ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 32, 32, 384)  1536       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 32, 32, 384)  0          ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_project_conv (Conv2D)  (None, 32, 32, 96)   36864       ['block3d_expand_activation[0][0]
#                                                                  ']
#
#  block3d_project_bn (BatchNorma  (None, 32, 32, 96)  384         ['block3d_project_conv[0][0]']
#  lization)
#
#  block3d_add (Add)              (None, 32, 32, 96)   0           ['block3d_project_bn[0][0]',
#                                                                   'block3c_add[0][0]']
#
#  block3e_expand_conv (Conv2D)   (None, 32, 32, 384)  331776      ['block3d_add[0][0]']
#
#  block3e_expand_bn (BatchNormal  (None, 32, 32, 384)  1536       ['block3e_expand_conv[0][0]']
#  ization)
#
#  block3e_expand_activation (Act  (None, 32, 32, 384)  0          ['block3e_expand_bn[0][0]']
#  ivation)
#
#  block3e_project_conv (Conv2D)  (None, 32, 32, 96)   36864       ['block3e_expand_activation[0][0]
#                                                                  ']
#
#  block3e_project_bn (BatchNorma  (None, 32, 32, 96)  384         ['block3e_project_conv[0][0]']
#  lization)
#
#  block3e_add (Add)              (None, 32, 32, 96)   0           ['block3e_project_bn[0][0]',
#                                                                   'block3d_add[0][0]']
#
#  block3f_expand_conv (Conv2D)   (None, 32, 32, 384)  331776      ['block3e_add[0][0]']
#
#  block3f_expand_bn (BatchNormal  (None, 32, 32, 384)  1536       ['block3f_expand_conv[0][0]']
#  ization)
#
#  block3f_expand_activation (Act  (None, 32, 32, 384)  0          ['block3f_expand_bn[0][0]']
#  ivation)
#
#  block3f_project_conv (Conv2D)  (None, 32, 32, 96)   36864       ['block3f_expand_activation[0][0]
#                                                                  ']
#
#  block3f_project_bn (BatchNorma  (None, 32, 32, 96)  384         ['block3f_project_conv[0][0]']
#  lization)
#
#  block3f_add (Add)              (None, 32, 32, 96)   0           ['block3f_project_bn[0][0]',
#                                                                   'block3e_add[0][0]']
#
#  block3g_expand_conv (Conv2D)   (None, 32, 32, 384)  331776      ['block3f_add[0][0]']
#
#  block3g_expand_bn (BatchNormal  (None, 32, 32, 384)  1536       ['block3g_expand_conv[0][0]']
#  ization)
#
#  block3g_expand_activation (Act  (None, 32, 32, 384)  0          ['block3g_expand_bn[0][0]']
#  ivation)
#
#  block3g_project_conv (Conv2D)  (None, 32, 32, 96)   36864       ['block3g_expand_activation[0][0]
#                                                                  ']
#
#  block3g_project_bn (BatchNorma  (None, 32, 32, 96)  384         ['block3g_project_conv[0][0]']
#  lization)
#
#  block3g_add (Add)              (None, 32, 32, 96)   0           ['block3g_project_bn[0][0]',
#                                                                   'block3f_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 32, 32, 384)  36864       ['block3g_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 32, 32, 384)  1536       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 32, 32, 384)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv2 (DepthwiseConv  (None, 16, 16, 384)  3456       ['block4a_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4a_bn (BatchNormalization  (None, 16, 16, 384)  1536       ['block4a_dwconv2[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 16, 16, 384)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 384)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 384)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 24)     9240        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 384)    9600        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 16, 16, 384)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 16, 16, 192)  73728       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 16, 16, 192)  768        ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 16, 16, 768)  147456      ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 16, 16, 768)  3072       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 16, 16, 768)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv2 (DepthwiseConv  (None, 16, 16, 768)  6912       ['block4b_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4b_bn (BatchNormalization  (None, 16, 16, 768)  3072       ['block4b_dwconv2[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 16, 16, 768)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 768)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 768)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 48)     36912       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 768)    37632       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 16, 16, 768)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 16, 16, 192)  147456      ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 16, 16, 192)  768        ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_add (Add)              (None, 16, 16, 192)  0           ['block4b_project_bn[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 16, 16, 768)  147456      ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 16, 16, 768)  3072       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 16, 16, 768)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv2 (DepthwiseConv  (None, 16, 16, 768)  6912       ['block4c_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4c_bn (BatchNormalization  (None, 16, 16, 768)  3072       ['block4c_dwconv2[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 16, 16, 768)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 768)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 768)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 48)     36912       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 768)    37632       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 16, 16, 768)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 16, 16, 192)  147456      ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 16, 16, 192)  768        ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_add (Add)              (None, 16, 16, 192)  0           ['block4c_project_bn[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)   (None, 16, 16, 768)  147456      ['block4c_add[0][0]']
#
#  block4d_expand_bn (BatchNormal  (None, 16, 16, 768)  3072       ['block4d_expand_conv[0][0]']
#  ization)
#
#  block4d_expand_activation (Act  (None, 16, 16, 768)  0          ['block4d_expand_bn[0][0]']
#  ivation)
#
#  block4d_dwconv2 (DepthwiseConv  (None, 16, 16, 768)  6912       ['block4d_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4d_bn (BatchNormalization  (None, 16, 16, 768)  3072       ['block4d_dwconv2[0][0]']
#  )
#
#  block4d_activation (Activation  (None, 16, 16, 768)  0          ['block4d_bn[0][0]']
#  )
#
#  block4d_se_squeeze (GlobalAver  (None, 768)         0           ['block4d_activation[0][0]']
#  agePooling2D)
#
#  block4d_se_reshape (Reshape)   (None, 1, 1, 768)    0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)     (None, 1, 1, 48)     36912       ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)     (None, 1, 1, 768)    37632       ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multiply)   (None, 16, 16, 768)  0           ['block4d_activation[0][0]',
#                                                                   'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)  (None, 16, 16, 192)  147456      ['block4d_se_excite[0][0]']
#
#  block4d_project_bn (BatchNorma  (None, 16, 16, 192)  768        ['block4d_project_conv[0][0]']
#  lization)
#
#  block4d_add (Add)              (None, 16, 16, 192)  0           ['block4d_project_bn[0][0]',
#                                                                   'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2D)   (None, 16, 16, 768)  147456      ['block4d_add[0][0]']
#
#  block4e_expand_bn (BatchNormal  (None, 16, 16, 768)  3072       ['block4e_expand_conv[0][0]']
#  ization)
#
#  block4e_expand_activation (Act  (None, 16, 16, 768)  0          ['block4e_expand_bn[0][0]']
#  ivation)
#
#  block4e_dwconv2 (DepthwiseConv  (None, 16, 16, 768)  6912       ['block4e_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4e_bn (BatchNormalization  (None, 16, 16, 768)  3072       ['block4e_dwconv2[0][0]']
#  )
#
#  block4e_activation (Activation  (None, 16, 16, 768)  0          ['block4e_bn[0][0]']
#  )
#
#  block4e_se_squeeze (GlobalAver  (None, 768)         0           ['block4e_activation[0][0]']
#  agePooling2D)
#
#  block4e_se_reshape (Reshape)   (None, 1, 1, 768)    0           ['block4e_se_squeeze[0][0]']
#
#  block4e_se_reduce (Conv2D)     (None, 1, 1, 48)     36912       ['block4e_se_reshape[0][0]']
#
#  block4e_se_expand (Conv2D)     (None, 1, 1, 768)    37632       ['block4e_se_reduce[0][0]']
#
#  block4e_se_excite (Multiply)   (None, 16, 16, 768)  0           ['block4e_activation[0][0]',
#                                                                   'block4e_se_expand[0][0]']
#
#  block4e_project_conv (Conv2D)  (None, 16, 16, 192)  147456      ['block4e_se_excite[0][0]']
#
#  block4e_project_bn (BatchNorma  (None, 16, 16, 192)  768        ['block4e_project_conv[0][0]']
#  lization)
# ...
#
#  block7f_se_squeeze (GlobalAver  (None, 3840)        0           ['block7f_activation[0][0]']
#  agePooling2D)
#
#  block7f_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7f_se_squeeze[0][0]']
#
#  block7f_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7f_se_reshape[0][0]']
#
#  block7f_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7f_se_reduce[0][0]']
#
#  block7f_se_excite (Multiply)   (None, 8, 8, 3840)   0           ['block7f_activation[0][0]',
#                                                                   'block7f_se_expand[0][0]']
#
#  block7f_project_conv (Conv2D)  (None, 8, 8, 640)    2457600     ['block7f_se_excite[0][0]']
#
#  block7f_project_bn (BatchNorma  (None, 8, 8, 640)   2560        ['block7f_project_conv[0][0]']
#  lization)
#
#  block7f_add (Add)              (None, 8, 8, 640)    0           ['block7f_project_bn[0][0]',
#                                                                   'block7e_add[0][0]']
#
#  block7g_expand_conv (Conv2D)   (None, 8, 8, 3840)   2457600     ['block7f_add[0][0]']
#
#  block7g_expand_bn (BatchNormal  (None, 8, 8, 3840)  15360       ['block7g_expand_conv[0][0]']
#  ization)
#
#  block7g_expand_activation (Act  (None, 8, 8, 3840)  0           ['block7g_expand_bn[0][0]']
#  ivation)
#
#  block7g_dwconv2 (DepthwiseConv  (None, 8, 8, 3840)  34560       ['block7g_expand_activation[0][0]
#  2D)                                                             ']
#
#  block7g_bn (BatchNormalization  (None, 8, 8, 3840)  15360       ['block7g_dwconv2[0][0]']
#  )
#
#  block7g_activation (Activation  (None, 8, 8, 3840)  0           ['block7g_bn[0][0]']
#  )
#
#  block7g_se_squeeze (GlobalAver  (None, 3840)        0           ['block7g_activation[0][0]']
#  agePooling2D)
#
#  block7g_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7g_se_squeeze[0][0]']
#
#  block7g_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7g_se_reshape[0][0]']
#
#  block7g_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7g_se_reduce[0][0]']
#
#  block7g_se_excite (Multiply)   (None, 8, 8, 3840)   0           ['block7g_activation[0][0]',
#                                                                   'block7g_se_expand[0][0]']
#
#  block7g_project_conv (Conv2D)  (None, 8, 8, 640)    2457600     ['block7g_se_excite[0][0]']
#
#  block7g_project_bn (BatchNorma  (None, 8, 8, 640)   2560        ['block7g_project_conv[0][0]']
#  lization)
#
#  block7g_add (Add)              (None, 8, 8, 640)    0           ['block7g_project_bn[0][0]',
#                                                                   'block7f_add[0][0]']
#
#  top_conv (Conv2D)              (None, 8, 8, 1280)   819200      ['block7g_add[0][0]']
#
#  top_bn (BatchNormalization)    (None, 8, 8, 1280)   5120        ['top_conv[0][0]']
#
#  top_activation (Activation)    (None, 8, 8, 1280)   0           ['top_bn[0][0]']
#
#  C5_reduced (Conv2D)            (None, 8, 8, 256)    327936      ['top_activation[0][0]']
#
#  C4_reduced (Conv2D)            (None, 16, 16, 256)  344320      ['block6a_expand_activation[0][0]
#                                                                  ']
#
#  P5_upsampled (UpSampling2D)    (None, 16, 16, 256)  0           ['C5_reduced[0][0]']
#
#  P4_merged (Add)                (None, 16, 16, 256)  0           ['C4_reduced[0][0]',
#                                                                   'P5_upsampled[0][0]']
#
#  C3_reduced (Conv2D)            (None, 32, 32, 256)  98560       ['block4a_expand_activation[0][0]
#                                                                  ']
#
#  P4_upsampled (UpSampling2D)    (None, 32, 32, 256)  0           ['P4_merged[0][0]']
#
#  P3_merged (Add)                (None, 32, 32, 256)  0           ['C3_reduced[0][0]',
#                                                                   'P4_upsampled[0][0]']
#
#  C2_reduced (Conv2D)            (None, 64, 64, 256)  16640       ['block2c_add[0][0]']
#
#  P3_upsampled (UpSampling2D)    (None, 64, 64, 256)  0           ['P3_merged[0][0]']
#
#  P2_merged (Add)                (None, 64, 64, 256)  0           ['C2_reduced[0][0]',
#                                                                   'P3_upsampled[0][0]']
#
#  C1_reduced (Conv2D)            (None, 128, 128, 25  8448        ['block1b_add[0][0]']
#                                 6)
#
#  P2_upsampled (UpSampling2D)    (None, 128, 128, 25  0           ['P2_merged[0][0]']
#                                 6)
#
#  P1_merged (Add)                (None, 128, 128, 25  0           ['C1_reduced[0][0]',
#                                 6)                                'P2_upsampled[0][0]']
#
#  P1 (Conv2D)                    (None, 128, 128, 25  590080      ['P1_merged[0][0]']
#                                 6)
#
#  conv_0_semantic_upsample_0 (Co  (None, 128, 128, 64  147520     ['P1[0][0]']
#  nv2D)                          )
#
#  conv_0_semantic_upsample_1 (Co  (None, 128, 128, 64  147520     ['P1[0][0]']
#  nv2D)                          )
#
#  conv_0_semantic_upsample_2 (Co  (None, 128, 128, 64  147520     ['P1[0][0]']
#  nv2D)                          )
#
#  upsampling_0_semantic_upsample  (None, 256, 256, 64  0          ['conv_0_semantic_upsample_0[0][0
#  _0 (UpSampling2D)              )                                ]']
#
#  upsampling_0_semantic_upsample  (None, 256, 256, 64  0          ['conv_0_semantic_upsample_1[0][0
#  _1 (UpSampling2D)              )                                ]']
#
#  upsampling_0_semantic_upsample  (None, 256, 256, 64  0          ['conv_0_semantic_upsample_2[0][0
#  _2 (UpSampling2D)              )                                ]']
#
#  conv_0_semantic_0 (Conv2D)     (None, 256, 256, 12  8320        ['upsampling_0_semantic_upsample_
#                                 8)                               0[0][0]']
#
#  conv_0_semantic_1 (Conv2D)     (None, 256, 256, 12  8320        ['upsampling_0_semantic_upsample_
#                                 8)                               1[0][0]']
#
#  conv_0_semantic_2 (Conv2D)     (None, 256, 256, 12  8320        ['upsampling_0_semantic_upsample_
#                                 8)                               2[0][0]']
#
#  batch_normalization_0_semantic  (None, 256, 256, 12  512        ['conv_0_semantic_0[0][0]']
#  _0 (BatchNormalization)        8)
#
#  batch_normalization_0_semantic  (None, 256, 256, 12  512        ['conv_0_semantic_1[0][0]']
#  _1 (BatchNormalization)        8)
#
#  batch_normalization_0_semantic  (None, 256, 256, 12  512        ['conv_0_semantic_2[0][0]']
#  _2 (BatchNormalization)        8)
#
#  relu_0_semantic_0 (Activation)  (None, 256, 256, 12  0          ['batch_normalization_0_semantic_
#                                 8)                               0[0][0]']
#
#  relu_0_semantic_1 (Activation)  (None, 256, 256, 12  0          ['batch_normalization_0_semantic_
#                                 8)                               1[0][0]']
#
#  relu_0_semantic_2 (Activation)  (None, 256, 256, 12  0          ['batch_normalization_0_semantic_
#                                 8)                               2[0][0]']
#
#  conv_1_semantic_0 (Conv2D)     (None, 256, 256, 1)  129         ['relu_0_semantic_0[0][0]']
#
#  conv_1_semantic_1 (Conv2D)     (None, 256, 256, 1)  129         ['relu_0_semantic_1[0][0]']
#
#  conv_1_semantic_2 (Conv2D)     (None, 256, 256, 2)  258         ['relu_0_semantic_2[0][0]']
#
#  semantic_0 (Activation)        (None, 256, 256, 1)  0           ['conv_1_semantic_0[0][0]']
#
#  semantic_1 (Activation)        (None, 256, 256, 1)  0           ['conv_1_semantic_1[0][0]']
#
#  semantic_2 (Softmax)           (None, 256, 256, 2)  0           ['conv_1_semantic_2[0][0]']
#
# ==================================================================================================
# Total params: 119,602,416
# Trainable params: 119,089,072
# Non-trainable params: 513,344
# __________________________________________________________________________________________________

# %%
print("Train data sequence length:", len(train_data))
print("Validation data sequence length:", len(val_data))
# Out:
# Train data sequence length: 162
# Validation data sequence length: 195

# %% [markdown]
# ## Save prediction model
#
# We can now create a new prediction model without the foreground background semantic head. While this head is very useful during training, the output is unused during prediction. By using `model.load_weights(path, by_name=True)`, the semantic head can be removed.

# %%
with tempfile.TemporaryDirectory() as tmpdirname:
    weights_path = os.path.join(str(tmpdirname), "model_weights.h5")
    model.save_weights(weights_path, save_format="h5")
    prediction_model = PanopticNet(
        backbone=backbone,
        input_shape=input_shape,
        norm_method=None,
        num_semantic_heads=2,
        num_semantic_classes=[1, 1],  # inner distance, outer distance
        location=location,  # should always be true
        include_top=True,
        backbone_levels=["C1", "C2", "C3", "C4", "C5"],
        pyramid_levels=pyramid_levels,
    )
    prediction_model.load_weights(weights_path, by_name=True)

# %% [markdown]
# ## Predict on test data

# %%
X_test = histograph_normalization(X_test)

test_images = prediction_model.predict(X_test)

# %%
index = np.random.choice(X_test.shape[0])
print(index)

fig, axes = plt.subplots(1, 4, figsize=(20, 20))

masks = deep_watershed(
    test_images,
    radius=radius,
    maxima_threshold=maxima_threshold,
    interior_threshold=interior_threshold,
    exclude_border=exclude_border,
    small_objects_threshold=small_objects_threshold,
    min_distance=min_distance
)

# calculated in the postprocessing above, but useful for visualizing
inner_distance = test_images[0]
outer_distance = test_images[1]

coords = peak_local_max(
    inner_distance[index],
    min_distance=min_distance
)

# raw image with centroid
axes[0].imshow(X_test[index, ..., 0])
axes[0].scatter(coords[..., 1], coords[..., 0],
                color='r', marker='.', s=10)

axes[1].imshow(inner_distance[index, ..., 0], cmap='jet')
axes[2].imshow(outer_distance[index, ..., 0], cmap='jet')
axes[3].imshow(masks[index, ...], cmap='jet')

plt.show()

# %% [markdown]
# ## Evaluate results
#
# The `deepcell.metrics` package is used to measure advanced metrics for instance segmentation predictions.

# %%
outputs = model.predict(X_test)

y_pred = []

for i in range(outputs[0].shape[0]):

    mask = deep_watershed(
        [t[[i]] for t in outputs],
        radius=radius,
        maxima_threshold=maxima_threshold,
        interior_threshold=interior_threshold,
        exclude_border=exclude_border,
        small_objects_threshold=small_objects_threshold,
        min_distance=min_distance)

    y_pred.append(mask[0])

y_pred = np.stack(y_pred, axis=0)
y_pred = np.expand_dims(y_pred, axis=-1)
y_true = y_test.copy()

m = Metrics('DeepWatershed', seg=False)
m.calc_object_stats(y_true, y_pred)
